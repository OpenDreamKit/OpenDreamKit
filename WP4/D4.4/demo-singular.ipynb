# %% [markdown]
# # Singular Jupyter kernel
#
# This notebook uses the Singular kernel for Jupyter and gives a first example of its usage.
#
# Below you will find a first example how to use Singular. We use the standard ring in Singular to create an ideal and
# compute its standard basis.
#
# Then we create a 3D-version of the Singular logo, using a polynomial and then printing an image using surf and the jupyter_surf.lib in Singular.

# %%
ring r; r;
# Out:
# //   characteristic : 32003
# //   number of vars : 3
# //        block   1 : ordering dp
# //                  : names    x y z
# //        block   2 : ordering C

# %%
ideal I = (xy,x^2);

# %%
std(I);
# Out:
# _[1]=xy
# _[2]=x2

# %%
poly logo = ((x+3)^3 + 2*(x+3)^2 - y^2)*(x^3 - y^2)*((x-3)^3-2*(x-3)^2-y^2);

# %%
LIB "surf_jupyter.lib";
# Out:
# // ** loaded /usr/local/src/sage-config/local/bin/../share/singular/LIB/surf_jupyter.lib (0.0.0.1,Jan_2016)

# %%
plot_jupyter(logo);
